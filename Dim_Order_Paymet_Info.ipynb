# %%
from pyspark.sql.readwriter import DataFrameWriter
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df_products = spark.sql("select payment_transaction_id,payment_type_value as PaymentType,payment_status \
from global_temp.payments p \
left outer join global_temp.payments_lookup pl on \
p.payment_type = pl.payment_type_id").cache()

df_products.write.mode('overwrite').format('csv').option('header','true').save('/mnt/salesanalytic/Sales/Transformed_Data/payment_Info/SparkSQLResult/')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
dbutils.notebook.exit('yay')
