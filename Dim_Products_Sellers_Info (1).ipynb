# %%
from pyspark.sql.functions import concat_ws
import pyspark.sql.readwriter

dim_ps_info_df = spark.sql("select p.product_id,s.seller_id,p.product_name,p.product_unit_cost,p.product_max_discount_price,s.seller_organization_name as product_seller,concat_ws(',',seller_address,seller_state,seller_city) as seller_address \
from global_temp.products p \
left outer join global_temp.sellers s on \
p.product_seller_id = s.seller_id")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#dim_ps_pyspa_df = df_products.join(sf_sellers,df_products['product_seller_id'] == sf_sellers['seller_id'],"left").select(['product_id','seller_id','product_name','product_unit_cost','product_max_discount_price',sf_sellers['seller_organization_name'].alias('product_seller'),concat_ws(',',sf_sellers['seller_address'],sf_sellers['seller_state'],sf_sellers['seller_city']).alias('seller_address')])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
dim_ps_info_df.write.option("header","true").mode('overwrite').save(path = '/mnt/salesanalytic/Sales/Transformed_Data/ProductSellerInfo/sparksqlresult',format = 'csv')
#dim_ps_pyspa_df.write.option("header","true").mode('overwrite').save(path = '/mnt/salesanalytic/ProductSellerInfo/sparkdataframeresult',format = 'csv')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
dbutils.notebook.exit('yay')
