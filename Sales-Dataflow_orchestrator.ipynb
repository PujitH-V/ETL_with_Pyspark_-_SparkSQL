# %%
executebook = dbutils.notebook.run("Sales_Load_Data",120)

if executebook == 'success':
  print('Notebook executed successfully!!!')
else:
  print('Notebook failed!!!')

NotebookA = dbutils.notebook.run("../Sales_Dimensions/Dim_Customers_Info",120)
NotebookB = dbutils.notebook.run("../Sales_Dimensions/Dim_Order_Paymet_Info",120)
NotebookC = dbutils.notebook.run("../Sales_Dimensions/Dim_Products_Sellers_Info",120)

if NotebookA == 'yay' and NotebookB == 'yay' and NotebookC == 'yay':
  print('Dimensions are Doneeeeeeeeeeeee')
else:
  print('Dimension table failed')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Notebook executed successfully!!!
# Dimensions are Doneeeeeeeeeeeee
# </div>

# %%
FactTable = dbutils.notebook.run("../Sales-Facts/Fact_Sales_Orders",120)

if FactTable == 'FFF':
  print('Fact table Doneeeeeeeeeeeee')
else:
  print('Fact table failed')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Fact table Doneeeeeeeeeeeee
# </div>
